# %%
import pandas as pd
df=pd.read_csv("all_parts_accuracies.csv")
df
# Out:
#     participant_id        LX        LY        RX        RY
# 0                1  0.591972  0.744697  0.688455  0.461161
# 1                2  0.181905  0.336311  0.435106  0.219649
# 2                3  0.259491  0.252453  0.289221  0.372159
# 3                4  0.611426  0.706680  0.442659  0.615502
# 4                5  0.396988  0.462742  0.383462  0.481590
# 5                6  0.692275  0.491817  0.365677  1.009295
# 6                7  0.522497  0.655545  0.500979  1.647926
# 7                8  0.267527  0.580054  0.779098  0.649295
# 8                9  0.213512  0.502933  0.300990  0.295410
# 9               10  0.488375  0.218192  0.241969  0.188994
# 10              11  0.407220  0.273154  0.771720  0.760581
# 11              12  0.353424  0.389253  0.303361  0.286863
# 12              13  0.325626  0.524029  0.329710  0.488136
# 13              14  0.384428  0.473191  0.210965  0.484011
# 14              15  0.421800  0.410547  0.470809  0.669379
# ...

# %%
#get accuracies:
(df['LX']).mean().round(3), (df['LY']).mean().round(3), (df['RX']).mean().round(3), (df['RY']).mean().round(3)
# Out:
# (np.float64(0.43672486525499227),
#  np.float64(0.5151322174095979),
#  np.float64(0.518696745651658),
#  np.float64(0.5700592461358958))
